# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/rushi0109/14July2018Hackathon/blob/master/hotstar_2.ipynb)

# %%
# !wget https://he-s3.s3.amazonaws.com/media/hackathon/machine-learning-indiahacks-2017/5f828822-4--4-hotstar_dataset.zip
# !unzip 5f828822-4--4-hotstar_dataset.zip
# Out:
# --2018-08-26 14:36:33--  https://he-s3.s3.amazonaws.com/media/hackathon/machine-learning-indiahacks-2017/5f828822-4--4-hotstar_dataset.zip
# Resolving he-s3.s3.amazonaws.com (he-s3.s3.amazonaws.com)... 52.219.32.76
# Connecting to he-s3.s3.amazonaws.com (he-s3.s3.amazonaws.com)|52.219.32.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51766669 (49M) [application/zip]
# Saving to: ‘5f828822-4--4-hotstar_dataset.zip’
#
# 5f828822-4--4-hotst 100%[===================>]  49.37M  8.98MB/s    in 15s
#
# 2018-08-26 14:36:49 (3.29 MB/s) - ‘5f828822-4--4-hotstar_dataset.zip’ saved [51766669/51766669]
#
# Archive:  5f828822-4--4-hotstar_dataset.zip
#   inflating: sample_submission.csv
#   inflating: test_data.json
#   inflating: train_data.json

# %%
import numpy as np
import pandas as pd
import re
train_data = pd.read_json('train_data.json',orient='index')

# %%
train_data['g1'] = [re.sub(pattern='\:\d+',repl='',string=x) for x in train_data['genres']]
train_data['g1'] = train_data['g1'].apply(lambda x: x.split(','))
t1 = pd.Series(train_data['g1']).apply(frozenset).to_frame(name='t_genre')
genreSet = frozenset.union(*t1.t_genre)

# %%
def string_genres_time(genre, string):
 if genre in string:
   prbmStr = string[string.index(genre) :]
   #print(prbmStr)
   problemStr = prbmStr[prbmStr.index(':')+1:]
   #print(problemStr)
   #print(problemStr.index(','))
   if ',' in problemStr:
     return int(problemStr[0:problemStr.index(',')])
   else:
     return int(problemStr[0:])
 else:
   return 0

# %%
def string_dow_time(genre, string):
 if genre in string:
   prbmStr = string[string.index(genre) :]
   #print(prbmStr)
   problemStr = prbmStr[prbmStr.index(':')+1:]
   #print(problemStr)
   #print(problemStr.index(','))
   if ',' in problemStr:
     return int(problemStr[0:problemStr.index(',')])
   else:
     return int(problemStr[0:])
 else:
   return 0

# %%
def string_tod_time(genre, string):
	if genre in string:
		prbmStr = string[string.index(genre) :]
		#print(prbmStr)
		problemStr = prbmStr[prbmStr.index(':')+1:]
		#print(problemStr)
		#print(problemStr.index(','))
		if ',' in problemStr:
			return int(problemStr[0:problemStr.index(',')])
		else:
			return int(problemStr[0:])
	else:
		todData = genre[1:]
		if todData in string:
			if string.index(todData) == 0:
				prbmStr = string[string.index(todData) :]
				#print(prbmStr)
				problemStr = prbmStr[prbmStr.index(':')+1:]
				#print(problemStr)
				#print(problemStr.index(','))
				if ',' in problemStr:
					return int(problemStr[0:problemStr.index(',')])
				else:
					return int(problemStr[0:])
			else:
				return 0
		else:
			return 0

# %%
for i in genreSet:
  train_data[i] = train_data["genres"].apply(lambda x : string_genres_time(i, x))

# %%
for i in np.arange(1,8):
  str_i = str(i) + ':'
  train_data[i] = train_data["dow"].apply(lambda x : string_dow_time(str_i, x))

# %%
for i in np.arange(0,24):
  str_i = ','+str(i)+':'
  colName = 'tod_'+str(i)
  train_data[colName] = train_data["tod"].apply(lambda x : string_genres_time(str_i, x))

# %%
train_data.drop(['g1','tod','dow','genres'],inplace=True,axis=1)

# %%
train_data.drop('cities',inplace=True,axis=1)

# %%
def get_int_value(param):
  return int(param[1:])

# %%
def getTimeList(titeString):
  return np.array([get_int_value(item) for item in re.findall('\:\d+',titeString)])

# %%
train_data['g2'] = [getTimeList(x) for x in train_data['titles']]
#train_data['g2'] = train_data['g2'].apply(lambda x: x.split(','))
#t1 = pd.Series(train_data['g2']).apply(frozenset).to_frame(name='t_titles')
#titlesSet = frozenset.union(*t1.t_titles)

# %%
train_data['title_mean'] = train_data['g2'].apply(np.mean)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)

# %%
train_data['title_median'] = train_data['g2'].apply(np.median)
train_data['title_sum'] = train_data['g2'].apply(np.sum)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)

# %%
train_data['title_count'] = train_data['g2'].apply(len)

# %%
train_data.drop('g2',inplace=True,axis=1)

# %%
train_data.drop('titles',axis=1,inplace=True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200000 entries, train-1 to train-99999
# Data columns (total 71 columns):
# segment         200000 non-null object
# Family          200000 non-null int64
# Tennis          200000 non-null int64
# Kids            200000 non-null int64
# Mythology       200000 non-null int64
# TalkShow        200000 non-null int64
# FormulaE        200000 non-null int64
# Hockey          200000 non-null int64
# Action          200000 non-null int64
# Crime           200000 non-null int64
# Football        200000 non-null int64
# Boxing          200000 non-null int64
# Athletics       200000 non-null int64
# Science         200000 non-null int64
# NA              200000 non-null int64
# Awards          200000 non-null int64
# Wildlife        200000 non-null int64
# Romance         200000 non-null int64
# Thriller        200000 non-null int64
# Horror          200000 non-null int64
# Badminton       200000 non-null int64
# Sport           200000 non-null int64
# Documentary     200000 non-null int64
# Cricket         200000 non-null int64
# Travel          200000 non-null int64
# Volleyball      200000 non-null int64
# Teen            200000 non-null int64
# Reality         200000 non-null int64
# LiveTV          200000 non-null int64
# Swimming        200000 non-null int64
# Comedy          200000 non-null int64
# Table Tennis    200000 non-null int64
# Kabaddi         200000 non-null int64
# Drama           200000 non-null int64
# Formula1        200000 non-null int64
# IndiaVsSa       200000 non-null int64
# 1               200000 non-null int64
# 2               200000 non-null int64
# 3               200000 non-null int64
# 4               200000 non-null int64
# 5               200000 non-null int64
# 6               200000 non-null int64
# 7               200000 non-null int64
# tod_0           200000 non-null int64
# tod_1           200000 non-null int64
# tod_2           200000 non-null int64
# tod_3           200000 non-null int64
# tod_4           200000 non-null int64
# tod_5           200000 non-null int64
# tod_6           200000 non-null int64
# tod_7           200000 non-null int64
# tod_8           200000 non-null int64
# tod_9           200000 non-null int64
# tod_10          200000 non-null int64
# tod_11          200000 non-null int64
# tod_12          200000 non-null int64
# tod_13          200000 non-null int64
# tod_14          200000 non-null int64
# tod_15          200000 non-null int64
# tod_16          200000 non-null int64
# tod_17          200000 non-null int64
# tod_18          200000 non-null int64
# tod_19          200000 non-null int64
# tod_20          200000 non-null int64
# tod_21          200000 non-null int64
# tod_22          200000 non-null int64
# tod_23          200000 non-null int64
# title_mean      199954 non-null float64
# title_median    199954 non-null float64
# title_sum       200000 non-null float64
# title_count     200000 non-null int64
# dtypes: float64(3), int64(67), object(1)
# memory usage: 114.9+ MB

# %%
all_cols = list(train_data.columns)

# %%
all_cols.remove('title_count')
all_cols.remove('segment')

# %%
train_data[all_cols] = train_data[all_cols]/60

# %%
train_data[all_cols] = train_data[all_cols].fillna(0)

# %%
train_data[all_cols] = train_data[all_cols].astype(int)

# %%
train_data['segment'].replace('pos',1,inplace=True)
train_data['segment'].replace('neg',0,inplace=True)

# %%
train_data.head().T
# Out:
#               train-1  train-10  train-100  train-1000  train-10000
# segment             0         0          0           0            0
# Family              0         0          0           0            0
# Tennis              0         0          0           0            0
# Kids                0         0          0           0            0
# Mythology           0         0          0           0            0
# TalkShow            0         0          0           0            0
# FormulaE            0         0          0           0            0
# Hockey              0         0          0           0            0
# Action              0         0          0           0            0
# Crime               0         0          0           0            0
# Football            0         0          1           0            0
# Boxing              0         0          0           0            0
# Athletics           0         0          0           0            0
# Science             0         0          0           0            0
# NA                  0         0          0           0            0
# Awards              0         0          0           0            0
# Wildlife            0         0          0           0            0
# Romance             0         0          0           0            0
# Thriller            0         0          0           0            0
# Horror              0         0          0           0            0
# Badminton           0         0          0           0            0
# Sport               0         0          0           0            0
# Documentary         0         0          0           0            0
# Cricket            22         4          0           2            0
# Travel              0         0          0           0            0
# Volleyball          0         0          0           0            0
# Teen                0         0          0           0            0
# Reality             1         0          0           0            0
# LiveTV              0         0          0           0            0
# Swimming            0         0          0           0            0
# ...               ...       ...        ...         ...          ...
# 6                   4         0          0           0            1
# 7                   4         0          0           0            0
# tod_0               0         0          0           0            0
# tod_1               0         0          0           0            0
# tod_2               0         0          0           0            0
# tod_3               0         0          0           0            0
# tod_4               0         0          0           0            0
# tod_5               0         0          0           0            0
# tod_6               0         0          0           0            0
# tod_7               0         0          0           0            0
# tod_8               0         0          0           0            0
# tod_9               0         0          0           0            0
# tod_10              0         0          0           0            0
# tod_11              0         0          0           0            0
# tod_12              0         0          0           0            0
# tod_13              0         0          0           0            0
# tod_14              0         0          0           0            0
# tod_15              0         0          0           0            0
# tod_16              0         0          0           0            0
# tod_17              2         0          0           0            0
# tod_18              1         0          0           0            0
# tod_19              3         1          0           0            0
# tod_20              6         0          0           0            0
# tod_21              4         0          0           0            0
# tod_22              2         0          0           0            1
# tod_23              1         0          0           0            0
# title_mean          0         0          0           0            0
# title_median        0         0          0           0            0
# title_sum          24         4          1           2            2
# title_count        60        70          2           8           11
#
# [71 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
y_label = train_data.pop('segment')

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data, y_label, test_size=0.3, random_state=9)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV,StratifiedKFold
from sklearn.metrics import roc_auc_score,accuracy_score,confusion_matrix
seed = 9

# %%
kf = StratifiedKFold(n_splits=5,shuffle=True,random_state=seed)
pred_test_full =0
cv_score =[]
i=1
for train_index,test_index in kf.split(X_train,y_train):
    print('{} of KFold {}'.format(i,kf.n_splits))
    xtr,xvl = X_train.iloc[train_index],X_train.iloc[test_index]
    ytr,yvl = y_train.iloc[train_index],y_train.iloc[test_index]
    
    #model
    lr = LogisticRegression()
    lr.fit(xtr,ytr)
    score = roc_auc_score(yvl,lr.predict(xvl))
    print('ROC AUC score:',score)
    cv_score.append(score)   
    print('Test Accuracy: ',accuracy_score(yvl,lr.predict(xvl)))
    print('Train Accuracy: ',accuracy_score(ytr,lr.predict(xtr)))
    print('Confusion Matrix: ',confusion_matrix(yvl,lr.predict(xvl)))
    i+=1
# Out:
# 1 of KFold 5
# ROC AUC score: 0.50500699342885
# Test Accuracy:  0.9228956108710403
# Train Accuracy:  0.922552879936428
# Confusion Matrix:  [[25817    43]
#  [ 2116    25]]
# 2 of KFold 5
# ROC AUC score: 0.5039746320175347
# Test Accuracy:  0.9229642857142857
# Train Accuracy:  0.9226964285714285
# Confusion Matrix:  [[25823    36]
#  [ 2121    20]]
# 3 of KFold 5
# ROC AUC score: 0.5035492482053223
# Test Accuracy:  0.9221785714285714
# Train Accuracy:  0.9227410714285714
# Confusion Matrix:  [[25801    58]
#  [ 2121    20]]
# 4 of KFold 5
# ROC AUC score: 0.5038794620754283
# Test Accuracy:  0.9223928571428571
# Train Accuracy:  0.9226607142857143
# Confusion Matrix:  [[25806    53]
#  [ 2120    21]]
# 5 of KFold 5
# ROC AUC score: 0.5037270687585768
# Test Accuracy:  0.9221400764313011
# Train Accuracy:  0.9225810483834965
# Confusion Matrix:  [[25798    61]
#  [ 2119    21]]

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler()
X_resampled, y_resampled = ros.fit_sample(X_train, y_train)

# %%
X_train.shape
# Out:
# (140000, 70)

# %%
kf = StratifiedKFold(n_splits=5,shuffle=True,random_state=seed)
pred_test_full =0
cv_score =[]
i=1
for train_index,test_index in kf.split(X_resampled,y_resampled):
    print('{} of KFold {}'.format(i,kf.n_splits))
    xtr,xvl = X_resampled[train_index],X_resampled[test_index]
    ytr,yvl = y_resampled[train_index],y_resampled[test_index]
    
    #model
    lr = LogisticRegression()
    lr.fit(xtr,ytr)
    score = roc_auc_score(yvl,lr.predict(xvl))
    print('ROC AUC score:',score)
    cv_score.append(score)   
    print('Test Accuracy: ',accuracy_score(yvl,lr.predict(xvl)))
    print('Train Accuracy: ',accuracy_score(ytr,lr.predict(xtr)))
    print('Confusion Matrix: ',confusion_matrix(yvl,lr.predict(xvl)))
    print('Validation Accuracy ',accuracy_score(y_test,lr.predict(X_test)))
    print('Validation Confusion Matrix: ',confusion_matrix(y_test,lr.predict(X_test)))
    print('------------------------------------------------------------------')
    i+=1
# Out:
# 1 of KFold 5
# ROC AUC score: 0.6841840680587781
# Test Accuracy:  0.6841840680587781
# Train Accuracy:  0.6815277079546773
# Confusion Matrix:  [[19763  6097]
#  [10237 15623]]
# Validation Accuracy  0.75055
# Validation Confusion Matrix:  [[42311 13138]
#  [ 1829  2722]]
# ------------------------------------------------------------------
# 2 of KFold 5
# ROC AUC score: 0.6844812251053792
# Test Accuracy:  0.6844812251053791
# Train Accuracy:  0.6815839593182323
# Confusion Matrix:  [[19802  6057]
#  [10261 15598]]
# Validation Accuracy  0.7509833333333333
# Validation Confusion Matrix:  [[42332 13117]
#  [ 1824  2727]]
# ------------------------------------------------------------------
# 3 of KFold 5
# ROC AUC score: 0.6816388878146874
# Test Accuracy:  0.6816388878146873
# Train Accuracy:  0.682309038351847
# Confusion Matrix:  [[19688  6171]
#  [10294 15565]]
# Validation Accuracy  0.7518833333333333
# Validation Confusion Matrix:  [[42393 13056]
#  [ 1831  2720]]
# ------------------------------------------------------------------
# 4 of KFold 5
# ROC AUC score: 0.6803820720058781
# Test Accuracy:  0.6803820720058781
# Train Accuracy:  0.6830921237081509
# Confusion Matrix:  [[19625  6234]
#  [10296 15563]]
# Validation Accuracy  0.7519833333333333
# Validation Confusion Matrix:  [[42398 13051]
#  [ 1830  2721]]
# ------------------------------------------------------------------
# 5 of KFold 5
# ROC AUC score: 0.6798793456823543
# Test Accuracy:  0.6798793456823543
# Train Accuracy:  0.6827199164708954
# Confusion Matrix:  [[19694  6165]
#  [10391 15468]]
# Validation Accuracy  0.7515333333333334
# Validation Confusion Matrix:  [[42373 13076]
#  [ 1832  2719]]
# ------------------------------------------------------------------

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
kf = StratifiedKFold(n_splits=5,shuffle=True,random_state=seed)
pred_test_full =0
cv_score =[]
i=1
for j in np.arange(1,100,5):
  for train_index,test_index in kf.split(X_resampled,y_resampled):
      print('{} of KFold {}'.format(i,kf.n_splits))
      xtr,xvl = X_resampled[train_index],X_resampled[test_index]
      ytr,yvl = y_resampled[train_index],y_resampled[test_index]

      #model
      lr = RandomForestClassifier(max_depth=j)
      lr.fit(xtr,ytr)
      score = roc_auc_score(yvl,lr.predict(xvl))
      print('ROC AUC score:',score)
      cv_score.append(score)   
      print('Test Accuracy: ',accuracy_score(yvl,lr.predict(xvl)))
      print('Train Accuracy: ',accuracy_score(ytr,lr.predict(xtr)))
      print('Confusion Matrix: ',confusion_matrix(yvl,lr.predict(xvl)))
      print('Validation Accuracy ',accuracy_score(y_test,lr.predict(X_test)))
      print('Validation Confusion Matrix: ',confusion_matrix(y_test,lr.predict(X_test)))
      print('------------------------------------------------------------------')
      i+=1
# Out:
# 1 of KFold 5
# ROC AUC score: 0.6661252900232018
# Test Accuracy:  0.6661252900232019
# Train Accuracy:  0.6602246799953595
# Confusion Matrix:  [[20982  4878]
#  [12390 13470]]
# Validation Accuracy  0.7862166666666667
# Validation Confusion Matrix:  [[44840 10609]
#  [ 2218  2333]]
# ------------------------------------------------------------------
# 2 of KFold 5
# ROC AUC score: 0.6533315286747361
# Test Accuracy:  0.6533315286747361
# Train Accuracy:  0.6566412405618879
# Confusion Matrix:  [[19740  6119]
#  [11810 14049]]
# Validation Accuracy  0.7506833333333334
# Validation Confusion Matrix:  [[42586 12863]
#  [ 2096  2455]]
# ------------------------------------------------------------------
# 3 of KFold 5
# ROC AUC score: 0.6352527166557097
# Test Accuracy:  0.6352527166557098
# Train Accuracy:  0.6383402457534538
# Confusion Matrix:  [[20577  5282]
#  [13582 12277]]
# Validation Accuracy  0.77375
# Validation Confusion Matrix:  [[44227 11222]
#  [ 2353  2198]]
# ------------------------------------------------------------------
# 4 of KFold 5
# ROC AUC score: 0.6457712981940524
# Test Accuracy:  0.6457712981940523
# Train Accuracy:  0.6463982907470247
# Confusion Matrix:  [[20506  5353]
#  [12967 12892]]
# Validation Accuracy  0.7720333333333333
# Validation Confusion Matrix:  [[44052 11397]
#  [ 2281  2270]]
# ------------------------------------------------------------------
# 5 of KFold 5
# ROC AUC score: 0.6615878417572219
# Test Accuracy:  0.6615878417572219
# Train Accuracy:  0.6641192223285671
# Confusion Matrix:  [[20442  5417]
#  [12085 13774]]
# Validation Accuracy  0.7719833333333334
# Validation Confusion Matrix:  [[43866 11583]
#  [ 2098  2453]]
# ------------------------------------------------------------------
# 6 of KFold 5
# ROC AUC score: 0.6861562258313998
# Test Accuracy:  0.6861562258313998
# Train Accuracy:  0.681092656328551
# Confusion Matrix:  [[20446  5414]
#  [10818 15042]]
# Validation Accuracy  0.77225
# Validation Confusion Matrix:  [[43739 11710]
#  [ 1955  2596]]
# ------------------------------------------------------------------
# 7 of KFold 5
# ROC AUC score: 0.6878649599752504
# Test Accuracy:  0.6878649599752504
# Train Accuracy:  0.690318744743177
# Confusion Matrix:  [[19840  6019]
#  [10124 15735]]
# Validation Accuracy  0.7561
# Validation Confusion Matrix:  [[42619 12830]
#  [ 1804  2747]]
# ------------------------------------------------------------------
# 8 of KFold 5
# ROC AUC score: 0.6865888085386133
# Test Accuracy:  0.6865888085386133
# Train Accuracy:  0.687399093167822
# Confusion Matrix:  [[20036  5823]
#  [10386 15473]]
# Validation Accuracy  0.7608666666666667
# Validation Confusion Matrix:  [[42956 12493]
#  [ 1855  2696]]
# ------------------------------------------------------------------
# 9 of KFold 5
# ROC AUC score: 0.6797246606597317
# Test Accuracy:  0.6797246606597316
# Train Accuracy:  0.680921720467531
# Confusion Matrix:  [[20606  5253]
#  [11311 14548]]
# Validation Accuracy  0.7802833333333333
# Validation Confusion Matrix:  [[44285 11164]
#  [ 2019  2532]]
# ------------------------------------------------------------------
# 10 of KFold 5
# ROC AUC score: 0.6859894040759502
# Test Accuracy:  0.6859894040759503
# Train Accuracy:  0.6904395912487794
# Confusion Matrix:  [[19624  6235]
#  [10005 15854]]
# Validation Accuracy  0.7500833333333333
# Validation Confusion Matrix:  [[42225 13224]
#  [ 1771  2780]]
# ------------------------------------------------------------------
# 11 of KFold 5
# ROC AUC score: 0.7086426914153133
# Test Accuracy:  0.7086426914153132
# Train Accuracy:  0.70566823929773
# Confusion Matrix:  [[20375  5485]
#  [ 9584 16276]]
# Validation Accuracy  0.7695166666666666
# Validation Confusion Matrix:  [[43480 11969]
#  [ 1860  2691]]
# ------------------------------------------------------------------
# 12 of KFold 5
# ROC AUC score: 0.7016125913608415
# Test Accuracy:  0.7016125913608415
# Train Accuracy:  0.705695254116032
# Confusion Matrix:  [[19809  6050]
#  [ 9382 16477]]
# Validation Accuracy  0.7552333333333333
# Validation Confusion Matrix:  [[42572 12877]
#  [ 1809  2742]]
# ------------------------------------------------------------------
# 13 of KFold 5
# ROC AUC score: 0.7047836343246066
# Test Accuracy:  0.7047836343246066
# Train Accuracy:  0.7087454199174377
# Confusion Matrix:  [[19681  6178]
#  [ 9090 16769]]
# Validation Accuracy  0.7515333333333334
# Validation Confusion Matrix:  [[42319 13130]
#  [ 1778  2773]]
# ------------------------------------------------------------------
# 14 of KFold 5
# ROC AUC score: 0.7036041610271085
# Test Accuracy:  0.7036041610271085
# Train Accuracy:  0.7060867967941838
# Confusion Matrix:  [[19925  5934]
#  [ 9395 16464]]
# Validation Accuracy  0.7608666666666667
# Validation Confusion Matrix:  [[42919 12530]
#  [ 1818  2733]]
# ------------------------------------------------------------------
# 15 of KFold 5
# ROC AUC score: 0.7013998994547352
# Test Accuracy:  0.7013998994547352
# Train Accuracy:  0.7068602144300395
# Confusion Matrix:  [[19922  5937]
#  [ 9506 16353]]
# Validation Accuracy  0.7593166666666666
# Validation Confusion Matrix:  [[42849 12600]
#  [ 1841  2710]]
# ------------------------------------------------------------------
# 16 of KFold 5
# ROC AUC score: 0.7323279195668988
# Test Accuracy:  0.7323279195668987
# Train Accuracy:  0.7349278781082021
# Confusion Matrix:  [[20744  5116]
#  [ 8728 17132]]
# Validation Accuracy  0.7797833333333334
# Validation Confusion Matrix:  [[44294 11155]
#  [ 2058  2493]]
# ------------------------------------------------------------------
# 17 of KFold 5
# ROC AUC score: 0.7365714064735682
# Test Accuracy:  0.7365714064735682
# Train Accuracy:  0.7457824569544748
# Confusion Matrix:  [[18027  7832]
#  [ 5792 20067]]
# Validation Accuracy  0.6965
# Validation Confusion Matrix:  [[38770 16679]
#  [ 1531  3020]]
# ------------------------------------------------------------------
# 18 of KFold 5
# ROC AUC score: 0.7380022429328281
# Test Accuracy:  0.738002242932828
# Train Accuracy:  0.7456906136102168
# Confusion Matrix:  [[17986  7873]
#  [ 5677 20182]]
# Validation Accuracy  0.69755
# Validation Confusion Matrix:  [[38828 16621]
#  [ 1526  3025]]
# ------------------------------------------------------------------
# 19 of KFold 5
# ROC AUC score: 0.7247186666151049
# Test Accuracy:  0.724718666615105
# Train Accuracy:  0.7328663824356855
# Confusion Matrix:  [[20824  5035]
#  [ 9202 16657]]
# Validation Accuracy  0.7868666666666667
# Validation Confusion Matrix:  [[44720 10729]
#  [ 2059  2492]]
# ------------------------------------------------------------------
# 20 of KFold 5
# ROC AUC score: 0.735527282570865
# Test Accuracy:  0.7355272825708651
# Train Accuracy:  0.7464591973858484
# Confusion Matrix:  [[17765  8094]
#  [ 5584 20275]]
# Validation Accuracy  0.6937166666666666
# Validation Confusion Matrix:  [[38560 16889]
#  [ 1488  3063]]
# ------------------------------------------------------------------
# 21 of KFold 5
# ROC AUC score: 0.7623356535189483
# Test Accuracy:  0.7623356535189482
# Train Accuracy:  0.771631733632391
# Confusion Matrix:  [[18824  7036]
#  [ 5256 20604]]
# Validation Accuracy  0.7168166666666667
# Validation Confusion Matrix:  [[40290 15159]
#  [ 1832  2719]]
# ------------------------------------------------------------------
# 22 of KFold 5
# ROC AUC score: 0.7569124869484511
# Test Accuracy:  0.7569124869484513
# Train Accuracy:  0.7715662673898122
# Confusion Matrix:  [[18691  7168]
#  [ 5404 20455]]
# Validation Accuracy  0.7163
# Validation Confusion Matrix:  [[40235 15214]
#  [ 1808  2743]]
# ------------------------------------------------------------------
# 23 of KFold 5
# ROC AUC score: 0.7595808035886925
# Test Accuracy:  0.7595808035886925
# Train Accuracy:  0.7727022245424752
# Confusion Matrix:  [[18662  7197]
#  [ 5237 20622]]
# Validation Accuracy  0.7152333333333334
# Validation Confusion Matrix:  [[40187 15262]
#  [ 1824  2727]]
# ------------------------------------------------------------------
# 24 of KFold 5
# ROC AUC score: 0.7560423836961986
# Test Accuracy:  0.7560423836961986
# Train Accuracy:  0.7691541711379873
# Confusion Matrix:  [[18445  7414]
#  [ 5203 20656]]
# Validation Accuracy  0.7082166666666667
# Validation Confusion Matrix:  [[39708 15741]
#  [ 1766  2785]]
# ------------------------------------------------------------------
# 25 of KFold 5
# ROC AUC score: 0.7565064387640666
# Test Accuracy:  0.7565064387640666
# Train Accuracy:  0.7716291075727254
# Confusion Matrix:  [[18607  7252]
#  [ 5341 20518]]
# Validation Accuracy  0.7180833333333333
# Validation Confusion Matrix:  [[40348 15101]
#  [ 1814  2737]]
# ------------------------------------------------------------------
# 26 of KFold 5
# ROC AUC score: 0.7796983758700696
# Test Accuracy:  0.7796983758700696
# Train Accuracy:  0.7934133183804478
# Confusion Matrix:  [[19416  6444]
#  [ 4950 20910]]
# Validation Accuracy  0.7336
# Validation Confusion Matrix:  [[41598 13851]
#  [ 2133  2418]]
# ------------------------------------------------------------------
# 27 of KFold 5
# ROC AUC score: 0.7778336362581693
# Test Accuracy:  0.7778336362581693
# Train Accuracy:  0.797664278739716
# Confusion Matrix:  [[19459  6400]
#  [ 5090 20769]]
# Validation Accuracy  0.7367
# Validation Confusion Matrix:  [[41890 13559]
#  [ 2239  2312]]
# ------------------------------------------------------------------
# 28 of KFold 5
# ROC AUC score: 0.7771955605398507
# Test Accuracy:  0.7771955605398507
# Train Accuracy:  0.79381169214111
# Confusion Matrix:  [[19338  6521]
#  [ 5002 20857]]
# Validation Accuracy  0.7338666666666667
# Validation Confusion Matrix:  [[41644 13805]
#  [ 2163  2388]]
# ------------------------------------------------------------------
# 29 of KFold 5
# ROC AUC score: 0.7790517808113229
# Test Accuracy:  0.779051780811323
# Train Accuracy:  0.7969633690072218
# Confusion Matrix:  [[19373  6486]
#  [ 4941 20918]]
# Validation Accuracy  0.7338333333333333
# Validation Confusion Matrix:  [[41657 13792]
#  [ 2178  2373]]
# ------------------------------------------------------------------
# 30 of KFold 5
# ROC AUC score: 0.7752426621292394
# Test Accuracy:  0.7752426621292393
# Train Accuracy:  0.7924388758374663
# Confusion Matrix:  [[19255  6604]
#  [ 5020 20839]]
# Validation Accuracy  0.7309166666666667
# Validation Confusion Matrix:  [[41504 13945]
#  [ 2200  2351]]
# ------------------------------------------------------------------
# 31 of KFold 5
# ROC AUC score: 0.7959783449342613
# Test Accuracy:  0.7959783449342615
# Train Accuracy:  0.8111005839359604
# Confusion Matrix:  [[20099  5761]
#  [ 4791 21069]]
# Validation Accuracy  0.7502
# Validation Confusion Matrix:  [[43020 12429]
#  [ 2559  1992]]
# ------------------------------------------------------------------
# 32 of KFold 5
# ROC AUC score: 0.7938048648439614
# Test Accuracy:  0.7938048648439615
# Train Accuracy:  0.8127652580797974
# Confusion Matrix:  [[20208  5651]
#  [ 5013 20846]]
# Validation Accuracy  0.7557666666666667
# Validation Confusion Matrix:  [[43394 12055]
#  [ 2599  1952]]
# ------------------------------------------------------------------
# 33 of KFold 5
# ROC AUC score: 0.7956030782319503
# Test Accuracy:  0.7956030782319502
# Train Accuracy:  0.8126637470150914
# Confusion Matrix:  [[20242  5617]
#  [ 4954 20905]]
# Validation Accuracy  0.7560166666666667
# Validation Confusion Matrix:  [[43449 12000]
#  [ 2639  1912]]
# ------------------------------------------------------------------
# 34 of KFold 5
# ROC AUC score: 0.7940175567500676
# Test Accuracy:  0.7940175567500677
# Train Accuracy:  0.813437164650947
# Confusion Matrix:  [[20003  5856]
#  [ 4797 21062]]
# Validation Accuracy  0.7504666666666666
# Validation Confusion Matrix:  [[43021 12428]
#  [ 2544  2007]]
# ------------------------------------------------------------------
# 35 of KFold 5
# ROC AUC score: 0.7908465137863026
# Test Accuracy:  0.7908465137863027
# Train Accuracy:  0.8117404797122887
# Confusion Matrix:  [[19856  6003]
#  [ 4814 21045]]
# Validation Accuracy  0.7504833333333333
# Validation Confusion Matrix:  [[42986 12463]
#  [ 2508  2043]]
# ------------------------------------------------------------------
# 36 of KFold 5
# ROC AUC score: 0.8075792730085074
# Test Accuracy:  0.8075792730085073
# Train Accuracy:  0.8211696121273058
# Confusion Matrix:  [[20665  5195]
#  [ 4757 21103]]
# Validation Accuracy  0.7652
# Validation Confusion Matrix:  [[44218 11231]
#  [ 2857  1694]]
# ------------------------------------------------------------------
# 37 of KFold 5
# ROC AUC score: 0.8038980625700917
# Test Accuracy:  0.8038980625700917
# Train Accuracy:  0.8238347979929812
# Confusion Matrix:  [[20503  5356]
#  [ 4786 21073]]
# Validation Accuracy  0.7634
# Validation Confusion Matrix:  [[44103 11346]
#  [ 2850  1701]]
# ------------------------------------------------------------------
# 38 of KFold 5
# ROC AUC score: 0.8045361382884102
# Test Accuracy:  0.8045361382884102
# Train Accuracy:  0.8209296479982985
# Confusion Matrix:  [[20342  5517]
#  [ 4592 21267]]
# Validation Accuracy  0.7584333333333333
# Validation Confusion Matrix:  [[43735 11714]
#  [ 2780  1771]]
# ------------------------------------------------------------------
# 39 of KFold 5
# ROC AUC score: 0.8040334119648865
# Test Accuracy:  0.8040334119648865
# Train Accuracy:  0.8227616810232316
# Confusion Matrix:  [[20547  5312]
#  [ 4823 21036]]
# Validation Accuracy  0.7655666666666666
# Validation Confusion Matrix:  [[44213 11236]
#  [ 2830  1721]]
# ------------------------------------------------------------------
# 40 of KFold 5
# ROC AUC score: 0.8037240419196412
# Test Accuracy:  0.8037240419196411
# Train Accuracy:  0.8231918945831762
# Confusion Matrix:  [[20479  5380]
#  [ 4771 21088]]
# Validation Accuracy  0.7674166666666666
# Validation Confusion Matrix:  [[44356 11093]
#  [ 2862  1689]]
# ------------------------------------------------------------------
# 41 of KFold 5
# ROC AUC score: 0.8143658159319412
# Test Accuracy:  0.8143658159319412
# Train Accuracy:  0.827487528520051
# Confusion Matrix:  [[20854  5006]
#  [ 4595 21265]]
# Validation Accuracy  0.7711
# Validation Confusion Matrix:  [[44717 10732]
#  [ 3002  1549]]
# ------------------------------------------------------------------
# 42 of KFold 5
# ROC AUC score: 0.8078425306469701
# Test Accuracy:  0.8078425306469701
# Train Accuracy:  0.8265514274389242
# Confusion Matrix:  [[20770  5089]
#  [ 4849 21010]]
# Validation Accuracy  0.7710666666666667
# Validation Confusion Matrix:  [[44660 10789]
#  [ 2947  1604]]
# ------------------------------------------------------------------
# 43 of KFold 5
# ROC AUC score: 0.8144553153640899
# Test Accuracy:  0.8144553153640899
# Train Accuracy:  0.8267157786865434
# Confusion Matrix:  [[21011  4848]
#  [ 4748 21111]]
# Validation Accuracy  0.7750666666666667
# Validation Confusion Matrix:  [[44971 10478]
#  [ 3018  1533]]
# ------------------------------------------------------------------
# 44 of KFold 5
# ROC AUC score: 0.8112069298890136
# Test Accuracy:  0.8112069298890136
# Train Accuracy:  0.8273780175372449
# Confusion Matrix:  [[20917  4942]
#  [ 4822 21037]]
# Validation Accuracy  0.7752666666666667
# Validation Confusion Matrix:  [[44999 10450]
#  [ 3034  1517]]
# ------------------------------------------------------------------
# 45 of KFold 5
# ROC AUC score: 0.8098921071967208
# Test Accuracy:  0.8098921071967207
# Train Accuracy:  0.8278372342585342
# Confusion Matrix:  [[20868  4991]
#  [ 4841 21018]]
# Validation Accuracy  0.7788333333333334
# Validation Confusion Matrix:  [[45203 10246]
#  [ 3024  1527]]
# ------------------------------------------------------------------
# 46 of KFold 5
# ROC AUC score: 0.8187354988399071
# Test Accuracy:  0.8187354988399071
# Train Accuracy:  0.8296144475811129
# Confusion Matrix:  [[21099  4761]
#  [ 4614 21246]]
# Validation Accuracy  0.7769166666666667
# Validation Confusion Matrix:  [[45216 10233]
#  [ 3152  1399]]
# ------------------------------------------------------------------
# 47 of KFold 5
# ROC AUC score: 0.8154414323833095

# %%
#for item in mylismap(get_int_value,re.findall('\:\d+',reString))
[get_int_value(item) for item in re.findall('\:\d+',reString)]
# Out:
# [103, 61593]

# %%
intString = ':103'

# %%
get_int_value(intString)
# Out:
# 103
